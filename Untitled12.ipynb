# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
df= yf.download('SPY,IWM,DIA', start='2012-07-10', end= '2022-07-10')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df.head()
# Out:
#              Adj Close                              Close             \
#                    DIA        IWM         SPY         DIA        IWM
# Date
# 2012-07-10  101.554420  69.260796  110.995560  126.349998  79.330002
# 2012-07-11  101.200775  69.025085  111.012077  125.910004  79.059998
# 2012-07-12  100.927475  68.789360  110.474243  125.570000  78.790001
# 2012-07-13  102.575249  69.644958  112.327759  127.620003  79.769997
# 2012-07-16  102.173286  69.365578  112.062958  127.120003  79.449997
#
#                               High                                Low  \
#                    SPY         DIA        IWM         SPY         DIA
# Date
# 2012-07-10  134.139999  128.139999  80.959999  136.229996  125.910004
# 2012-07-11  134.160004  126.489998  79.650002  134.600006  125.190002
# 2012-07-12  133.509995  126.160004  79.099998  134.229996  124.769997
# 2012-07-13  135.750000  127.709999  80.089996  135.889999  125.860001
# ...

# %%
df.tail()
# Out:
#              Adj Close                               Close              \
#                    DIA         IWM         SPY         DIA         IWM
# Date
# 2022-07-01  310.720154  171.410004  381.239990  310.850006  171.410004
# 2022-07-05  309.580597  172.830002  381.959991  309.709991  172.830002
# 2022-07-06  310.280334  171.550003  383.250000  310.410004  171.550003
# 2022-07-07  313.818848  175.610001  388.989990  313.950012  175.610001
# 2022-07-08  313.329041  175.589996  388.670013  313.459991  175.589996
#
#                               High                                 Low  \
#                    SPY         DIA         IWM         SPY         DIA
# Date
# 2022-07-01  381.239990  311.309998  171.839996  381.700012  304.769989
# 2022-07-05  381.959991  309.760010  172.899994  381.980011  303.579987
# 2022-07-06  383.250000  312.290009  173.710007  385.869995  307.940002
# 2022-07-07  388.989990  314.269989  175.979996  389.829987  311.609985
# ...

# %%
df.shape
# Out:
# (2516, 18)

# %%
df.columns
# Out:
# MultiIndex([('Adj Close', 'DIA'),
#             ('Adj Close', 'IWM'),
#             ('Adj Close', 'SPY'),
#             (    'Close', 'DIA'),
#             (    'Close', 'IWM'),
#             (    'Close', 'SPY'),
#             (     'High', 'DIA'),
#             (     'High', 'IWM'),
#             (     'High', 'SPY'),
#             (      'Low', 'DIA'),
#             (      'Low', 'IWM'),
#             (      'Low', 'SPY'),
#             (     'Open', 'DIA'),
#             (     'Open', 'IWM'),
#             (     'Open', 'SPY'),
#             (   'Volume', 'DIA'),
#             (   'Volume', 'IWM'),
#             (   'Volume', 'SPY')],
#            )

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Adj Close  DIA    0
#            IWM    0
#            SPY    0
# Close      DIA    0
#            IWM    0
#            SPY    0
# High       DIA    0
#            IWM    0
#            SPY    0
# Low        DIA    0
#            IWM    0
#            SPY    0
# Open       DIA    0
#            IWM    0
#            SPY    0
# Volume     DIA    0
#            IWM    0
#            SPY    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2012-07-10 to 2022-07-08
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Adj Close, DIA)  2516 non-null   float64
#  1   (Adj Close, IWM)  2516 non-null   float64
#  2   (Adj Close, SPY)  2516 non-null   float64
#  3   (Close, DIA)      2516 non-null   float64
#  4   (Close, IWM)      2516 non-null   float64
#  5   (Close, SPY)      2516 non-null   float64
#  6   (High, DIA)       2516 non-null   float64
#  7   (High, IWM)       2516 non-null   float64
#  8   (High, SPY)       2516 non-null   float64
#  9   (Low, DIA)        2516 non-null   float64
#  10  (Low, IWM)        2516 non-null   float64
#  11  (Low, SPY)        2516 non-null   float64
#  12  (Open, DIA)       2516 non-null   float64
#  13  (Open, IWM)       2516 non-null   float64
#  14  (Open, SPY)       2516 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Adj Close                                  Close               \
#                DIA          IWM          SPY          DIA          IWM
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean    206.670683   134.435361   243.858225   225.116340   141.820986
# std      72.821015    41.252453    94.147235    65.725848    38.424204
# min     100.927475    66.920975   110.474243   125.510002    76.650002
# 25%     144.204029   103.886679   172.945915   170.202503   114.117502
# 50%     193.256271   128.957550   222.831001   213.735001   137.125000
# 75%     253.934441   153.144623   286.998116   267.132500   158.332497
# max     364.222107   240.716629   474.182190   367.869995   242.559998
#
#                            High                                    Low  \
#                SPY          DIA          IWM          SPY          DIA
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# ...

# %%
df.nunique()
# Out:
# Adj Close  DIA    2476
#            IWM    2454
#            SPY    2457
# Close      DIA    2311
#            IWM    2218
#            SPY    2372
# High       DIA    2312
#            IWM    2217
#            SPY    2361
# Low        DIA    2326
#            IWM    2210
#            SPY    2354
# Open       DIA    2306
#            IWM    2214
#            SPY    2379
# Volume     DIA    2474
#            IWM    2505
#            SPY    2515
# dtype: int64

# %%
df1= df['Adj Close'].mean()

# %%
df= pd.concat([df1], axis=1)

# %%
# User Input
current_age = int(input("What is your current age? "))
retire_age = int(input("What age will you retire? "))
# Out:
# What is your current age? 24
# What age will you retire? 64

# %%
balance = int(
        input("What is your current retirement account balance? ").replace(",", "")
    )
annual_contrib = int(
        input("What is your expected annual contribution? ").replace(",", "")
    )
benchmark = input("Which benchmark do you want to use? SPY | IWM | DIA ")
salary = int(input("What is your current annual salary? ").replace(",", ""))
four_oh_one_rate = (
        int(input("What is the 401k matching rate of your firm? (in whole number %)"))
        / 100
    )
retire_target = int(
        input("How much money do you need to retire? ").replace(",", "")
    )

# %%
# Check for 401k matching level, calculate company match
        if (self.annual_contrib / self.salary) >= self.four_oh_one_rate:
# 401k Matching calculation
            self.four_oh_one_match = self.salary * self.four_oh_one_rate
        else:
# 401k matching calculation
            self.four_oh_one_match = self.salary * (
                self.annual_contrib / self.salary
            )

# %%
# Set baseline balance and age based on Class local variables
        self.while_balance = self.balance
        self.while_age = self.current_age

# Calculate balance and age until retirement target is reached
        while self.while_balance < self.retire_target:

 # End of period balance calculation
            self.while_balance = (
                (self.while_balance * (self.rate_of_return + 1))
                + self.annual_contrib
                + self.four_oh_one_match
            )
            self.while_age += 1

        return (
            self.while_age,
            round(self.while_balance, 0),
            self.bench_data,
        )
